# %% [markdown]
# Lets visualize a sample RX image of a hand

# %%
from PIL import Image
from matplotlib import pyplot as plt

img = Image.open("data/boneage-test-dataset/9755.png")

plt.imshow(img, cmap="gray")
plt.show()

# %% [markdown]
# This is the hand of a 106‑month‑old female subject.

# %%
# !python -m  BoneAgeRegressor --image data/boneage-test-dataset/9755.png --sex female
# Out:
# Bone age prediction (months): 107.55
# Bone age prediction (years): 8.9625
# ...
