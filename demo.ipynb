# %% [markdown]
# Lets visualize a sample RX image of a hand

# %%
from PIL import Image
from matplotlib import pyplot as plt

img = Image.open("data/boneage-test-dataset/9727.png")

plt.imshow(img, cmap="gray")
plt.show()

# %% [markdown]
# This is the hand of a 120‑month‑old female subject.

# %%
# !python -m  BoneAgeRegressor --image data/boneage-test-dataset/9727.png --sex female
# Out:
# Bone age prediction (months): 114.05
# Bone age prediction (years): 9.5
# ...
